# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import math
from scipy.fftpack import fft2
from scipy.fftpack import fftshift
import os

# %%
# https://stackoverflow.com/questions/30230592/loading-all-images-using-imread-from-a-given-folder
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# %%
fourierTransform = fft2
# images = ["box1.png", "box2.png", "box3.png", "box4.png", "oval1.png", "oval2.png", "oval3.png", "rectangle1.png", "rectangle2.png","rounded1.png", "triangle1.png"]
images = load_images_from_folder("./")
for image in images:
    fig = plt.figure()
    ax = plt.axes()
    
#     ax.set_title(img, loc='left')
    image = image / 255.0
    image = image[:,:,0]
    gray = image
    transform = []
    
    plt.title("Original")
    plt.imshow(gray, cmap='gray')
    plt.show()

    transform = fftshift(fft2(gray))
#     transform = math.log(abs(transform) + 1)
    
    plt.title(" Transformed")
#     plt.imshow(np.array(transform, dtype=float))
    plt.imshow(np.absolute(transform), cmap='gray')
    plt.show()
